# %%
import sympy

g, m = sympy.symbols('g m')

t = sympy.Symbol('t')
vx = sympy.Function('v_x')(t)
vy = sympy.Function('v_y')(t)
vz = sympy.Function('v_z')(t)

phi_d = sympy.atan2(-vy, vz + g)
theta_d = sympy.atan2(vx*sympy.cos(phi_d), vz + g)
F_d = m*(vz + g)/(sympy.cos(phi_d)*sympy.cos(theta_d))

from IPython.display import display, Math

subs = [
    (sympy.Derivative(vx, t, 2), sympy.Symbol('v2(0)')),
    (sympy.Derivative(vy, t, 2), sympy.Symbol('v2(1)')),
    (sympy.Derivative(vz, t, 2), sympy.Symbol('v2(2)')),
    (sympy.Derivative(vx, t), sympy.Symbol('v1(0)')),
    (sympy.Derivative(vy, t), sympy.Symbol('v1(1)')),
    (sympy.Derivative(vz, t), sympy.Symbol('v1(2)')),
    (vx, sympy.Symbol('v(0)')),
    (vy, sympy.Symbol('v(1)')),
    (vz, sympy.Symbol('v(2)')),
    (m, sympy.Symbol('Params::m')),
    (g, sympy.Symbol('Params::g')),
]

display(Math('F_d = ' + sympy.latex(sympy.simplify(F_d))))

print(sympy.ccode(sympy.simplify(F_d).subs(subs)))

display(Math('\\phi_d         = ' + sympy.latex(sympy.simplify(phi_d))))
display(Math('\\dot{\\phi}_d  = ' + sympy.latex(sympy.simplify(phi_d.diff(t)))))
display(Math('\\ddot{\\phi}_d = ' + sympy.latex(sympy.simplify(phi_d.diff(t, 2)))))

print(sympy.ccode(sympy.simplify(phi_d.subs(subs))))
print(sympy.ccode(sympy.simplify(phi_d.diff(t).subs(subs))))
print(sympy.ccode(sympy.simplify(phi_d.diff(t, 2).subs(subs))))

display(Math('\\theta_d         = ' + sympy.latex(sympy.simplify(theta_d))))
display(Math('\\dot{\\theta}_d  = ' + sympy.latex(sympy.simplify(theta_d.diff(t)))))
display(Math('\\ddot{\\theta}_d = ' + sympy.latex(sympy.simplify(theta_d.diff(t, 2)))))

print(sympy.ccode(sympy.simplify(theta_d.subs(subs))))
print(sympy.ccode(sympy.simplify(theta_d.diff(t).subs(subs))))
print(sympy.ccode(sympy.simplify(theta_d.diff(t, 2).subs(subs))))
# Out:
# $\displaystyle F_d = \frac{m \sqrt{\frac{\left(g + v_{z}{\left(t \right)}\right)^{2} \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{x}^{2}{\left(t \right)} + v_{y}^{2}{\left(t \right)}\right)}{\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}}} \sqrt{\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}}}{g + v_{z}{\left(t \right)}}$
# Params::m*sqrt(pow(Params::g + v(2), 2)*(pow(v(0), 2) + pow(v(1), 2) + pow(Params::g + v(2), 2))/(pow(v(1), 2) + pow(Params::g + v(2), 2)))*sqrt(pow(v(1), 2) + pow(Params::g + v(2), 2))/(Params::g + v(2))
# $\displaystyle \phi_d         = \operatorname{atan}_{2}{\left(- v_{y}{\left(t \right)},g + v_{z}{\left(t \right)} \right)}$
# $\displaystyle \dot{\phi}_d  = \frac{- \left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{y}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}}{\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}}$
# $\displaystyle \ddot{\phi}_d = \frac{2 \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right) \frac{d}{d t} v_{y}{\left(t \right)} + \left(- \left(g + v_{z}{\left(t \right)}\right) \frac{d^{2}}{d t^{2}} v_{y}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d^{2}}{d t^{2}} v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right) - 2 \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right) v_{y}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}}{\left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right)^{2}}$
# atan2(-v(1), Params::g + v(2))
# (v(1)*v1(2) - v1(1)*(Params::g + v(2)))/(pow(v(1), 2) + pow(Params::g + v(2), 2))
# (-2*v(1)*v1(2)*(v(1)*v1(1) + v1(2)*(Params::g + v(2))) + 2*v1(1)*(Params::g + v(2))*(v(1)*v1(1) + v1(2)*(Params::g + v(2))) - (pow(v(1), 2) + pow(Params::g + v(2), 2))*(-v(1)*v2(2) + v2(1)*(Params::g + v(2))))/pow(pow(v(1), 2) + pow(Params::g + v(2), 2), 2)
# $\displaystyle \theta_d         = \operatorname{atan}_{2}{\left(\frac{\left(g + v_{z}{\left(t \right)}\right) v_{x}{\left(t \right)}}{\sqrt{\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}}},g + v_{z}{\left(t \right)} \right)}$
# $\displaystyle \dot{\theta}_d  = \frac{- \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right) v_{x}{\left(t \right)} + \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{x}{\left(t \right)} + v_{x}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right) - \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right) v_{x}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}}{\left(g + v_{z}{\left(t \right)}\right) \sqrt{\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}} \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{x}^{2}{\left(t \right)} + v_{y}^{2}{\left(t \right)}\right)}$
# $\displaystyle \ddot{\theta}_d = \frac{3 \left(g + v_{z}{\left(t \right)}\right)^{2} \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right)^{2} \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{x}^{2}{\left(t \right)} + v_{y}^{2}{\left(t \right)}\right) v_{x}{\left(t \right)} + \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d^{2}}{d t^{2}} v_{x}{\left(t \right)} + \frac{d}{d t} v_{x}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right)^{2} \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{x}^{2}{\left(t \right)} + v_{y}^{2}{\left(t \right)}\right) - \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right) \left(2 \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right) \frac{d}{d t} v_{x}{\left(t \right)} + \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d^{2}}{d t^{2}} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d^{2}}{d t^{2}} v_{y}{\left(t \right)} + \left(\frac{d}{d t} v_{y}{\left(t \right)}\right)^{2} + \left(\frac{d}{d t} v_{z}{\left(t \right)}\right)^{2}\right) v_{x}{\left(t \right)} + \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right) v_{x}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{x}^{2}{\left(t \right)} + v_{y}^{2}{\left(t \right)}\right) + \left(- \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right) v_{x}{\left(t \right)} + \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{x}{\left(t \right)} + v_{x}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right)\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{x}^{2}{\left(t \right)} + v_{y}^{2}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} - 2 \left(- \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right) v_{x}{\left(t \right)} + \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{x}{\left(t \right)} + v_{x}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right)\right) \left(- \left(g + v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{z}{\left(t \right)} + v_{y}{\left(t \right)} \frac{d}{d t} v_{y}{\left(t \right)}\right) v_{x}^{2}{\left(t \right)} + \left(\left(g + v_{z}{\left(t \right)}\right) \frac{d}{d t} v_{x}{\left(t \right)} + v_{x}{\left(t \right)} \frac{d}{d t} v_{z}{\left(t \right)}\right) \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right) v_{x}{\left(t \right)} + \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right)^{2} \frac{d}{d t} v_{z}{\left(t \right)}\right) - \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y}^{2}{\left(t \right)}\right)^{2} \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{x}^{2}{\left(t \right)} + v_{y}^{2}{\left(t \right)}\right) v_{x}{\left(t \right)} \left(\frac{d}{d t} v_{z}{\left(t \right)}\right)^{2} + 2 \left(\left(g + v_{z}{\left(t \right)}\right)^{2} + v_{y ...
# atan2(v(0)*(Params::g + v(2))/sqrt(pow(v(1), 2) + pow(Params::g + v(2), 2)), Params::g + v(2))
# (-v(0)*v1(2)*(pow(v(1), 2) + pow(Params::g + v(2), 2)) - v(0)*(Params::g + v(2))*(v(1)*v1(1) + v1(2)*(Params::g + v(2))) + (pow(v(1), 2) + pow(Params::g + v(2), 2))*(v(0)*v1(2) + v1(0)*(Params::g + v(2))))/((Params::g + v(2))*sqrt(pow(v(1), 2) + pow(Params::g + v(2), 2))*(pow(v(0), 2) + pow(v(1), 2) + pow(Params::g + v(2), 2)))
# (-v(0)*pow(v1(2), 2)*pow(pow(v(1), 2) + pow(Params::g + v(2), 2), 2)*(pow(v(0), 2) + pow(v(1), 2) + pow(Params::g + v(2), 2)) + 2*v(0)*v1(2)*(pow(v(1), 2) + pow(Params::g + v(2), 2))*(-pow(v(0), 2)*(Params::g + v(2))*(v(1)*v1(1) + v1(2)*(Params::g + v(2))) + v(0)*(pow(v(1), 2) + pow(Params::g + v(2), 2))*(v(0)*v1(2) + v1(0)*(Params::g + v(2))) + v1(2)*pow(pow(v(1), 2) + pow(Params::g + v(2), 2), 2)) + 3*v(0)*pow(Params::g + v(2), 2)*pow(v(1)*v1(1) + v1(2)*(Params::g + v(2)), 2)*(pow(v(0), 2) + pow(v(1), 2) + pow(Params::g + v(2), 2)) + v1(2)*(pow(v(1), 2) + pow(Params::g + v(2), 2))*(-v(0)*(Params::g + v(2))*(v(1)*v1(1) + v1(2)*(Params::g + v(2))) + (pow(v(1), 2) + pow(Params::g + v(2), 2))*(v(0)*v1(2) + v1(0)*(Params::g + v(2))))*(pow(v(0), 2) + pow(v(1), 2) + pow(Params::g + v(2), 2)) + (Params::g + v(2))*pow(pow(v(1), 2) + pow(Params::g + v(2), 2), 2)*(v1(0)*v1(2) + v2(0)*(Params::g + v(2)))*(pow(v(0), 2) + pow(v(1), 2) + pow(Params::g + v(2), 2)) - (Params::g + v(2))*(pow(v(1), 2) + pow(Params::g + v(2), 2))*(pow(v(0), 2) + pow(v(1), 2) + pow(Params::g + v(2), 2))*(v(0)*v1(2)*(v(1)*v1(1) + v1(2)*(Params::g + v(2))) + v(0)*(Params::g + v(2))*(v(1)*v2(1) + pow(v1(1), 2) + pow(v1(2), 2) + v2(2)*(Params::g + v(2))) + 2*v1(0)*(Params::g + v(2))*(v(1)*v1(1) + v1(2)*(Params::g + v(2)))) - 2*(-v(0)*(Params::g + v(2))*(v(1)*v1(1) + v1(2)*(Params::g + v(2))) + (pow(v(1), 2) + pow(Params::g + v(2), 2))*(v(0)*v1(2) + v1(0)*(Params::g + v(2))))*(-pow(v(0), 2)*(Params::g + v(2))*(v(1)*v1(1) + v1(2)*(Params::g + v(2))) + v(0)*(pow(v(1), 2) + pow(Params::g + v(2), 2))*(v(0)*v1(2) + v1(0)*(Params::g + v(2))) + v1(2)*pow(pow(v(1), 2) + pow(Params::g + v(2), 2), 2)))/(pow(Params::g + v(2), 2)*pow(pow(v(1), 2) + pow(Params::g + v(2), 2), 3.0/2.0)*pow(pow(v(0), 2) + pow(v(1), 2) + pow(Params::g + v(2), 2), 2))

# %%
w, a = sympy.symbols('w a')

x_ref = a*sympy.sin(w*t)*sympy.cos(w*t)/(1 + sympy.sin(w*t)**2)
y_ref = a*sympy.cos(w*t)/(1 + sympy.sin(w*t)**2)
z_ref = sympy.Number(1)
psi_ref = sympy.atan2(y_ref.diff(t), x_ref.diff(t))

print(sympy.pycode(x_ref))
print(sympy.pycode(y_ref))
print(sympy.pycode(z_ref))
print(sympy.pycode(psi_ref))

print(sympy.pycode(sympy.simplify(x_ref.diff(t))))
print(sympy.pycode(sympy.simplify(y_ref.diff(t))))
print(sympy.pycode(sympy.simplify(z_ref.diff(t))))
print(sympy.pycode(sympy.simplify(psi_ref.diff(t))))
# Out:
# a*math.sin(t*w)*math.cos(t*w)/(math.sin(t*w)**2 + 1)
# a*math.cos(t*w)/(math.sin(t*w)**2 + 1)
# 1
# math.atan2(-a*w*math.sin(t*w)/(math.sin(t*w)**2 + 1) - 2*a*w*math.sin(t*w)*math.cos(t*w)**2/(math.sin(t*w)**2 + 1)**2, -a*w*math.sin(t*w)**2/(math.sin(t*w)**2 + 1) + a*w*math.cos(t*w)**2/(math.sin(t*w)**2 + 1) - 2*a*w*math.sin(t*w)**2*math.cos(t*w)**2/(math.sin(t*w)**2 + 1)**2)
# a*w*(1 - 3*math.sin(t*w)**2)/(math.sin(t*w)**2 + 1)**2
# a*w*(math.sin(t*w)**2 - 3)*math.sin(t*w)/(math.sin(t*w)**2 + 1)**2
# 0
# -3*w*math.cos(t*w)/(math.sin(t*w)**2 + 1)

# %%
import sympy

t = sympy.Symbol('t')
psi = sympy.Function('\\psi')(t)
R = sympy.Function('R')(psi)

sympy.simplify(sympy.Derivative(R, t))
# Out:
# Derivative(R(\psi(t)), \psi(t))*Derivative(\psi(t), t)

# %%
sympy.simplify(sympy.Derivative(sympy.simplify(sympy.Derivative(R, t)), t))
# Out:
# Derivative(R(\psi(t)), \psi(t))*Derivative(\psi(t), (t, 2)) + Derivative(R(\psi(t)), (\psi(t), 2))*Derivative(\psi(t), t)**2

# %%
k1, k0 = sympy.symbols('K_d K_p')
v = sympy.Function('v')(t)
e = sympy.Function('e')(t)
q2 = (R**-1)*(R*v + k1*sympy.Derivative(e, t) + k0*e)

sympy.simplify(sympy.Derivative(q2, t))
# Out:
# -(K_d*Derivative(e(t), t) + K_p*e(t) + R(\psi(t))*v(t))*Derivative(R(\psi(t)), \psi(t))*Derivative(\psi(t), t)/R(\psi(t))**2 + (K_d*Derivative(e(t), (t, 2)) + K_p*Derivative(e(t), t) + R(\psi(t))*Derivative(v(t), t) + v(t)*Derivative(R(\psi(t)), \psi(t))*Derivative(\psi(t), t))/R(\psi(t))
